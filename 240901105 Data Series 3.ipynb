# %% [markdown]
# <a href="https://colab.research.google.com/github/sxddxrth/PPML-/blob/main/240901105%20Data%20Series%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime

#create a date variable that contains the dates
dates = [datetime(2011, 1, 2),
datetime(2011, 1, 5),
datetime(2011, 1, 7),
datetime(2011, 1, 8),
datetime(2011, 1, 10),
datetime(2011, 1, 12)]

#with this date object, create a series
ts = pd.Series(np.random.randn(6), index=dates)
print("Date Index \n",ts)
# Out:
# Date Index
#  2011-01-02   -1.873247
# 2011-01-05   -1.389749
# 2011-01-07    0.275245
# 2011-01-08   -0.847082
# 2011-01-10    0.866987
# 2011-01-12    1.105259
# dtype: float64

# %%
print("\nDate Index alone from the series: \n",ts.index)
# Out:
# Date Index alone from the series:
#  DatetimeIndex(['2011-01-02', '2011-01-05', '2011-01-07', '2011-01-08',
#                '2011-01-10', '2011-01-12'],
#               dtype='datetime64[ns]', freq=None)

# %%
stamp=ts.index[2]
print("\nSecond index:\n", stamp)
# Out:
# Second index:
#  2011-01-07 00:00:00

# %%
#play like a ball with long-times series
longer_ts=pd.Series(np.random.randn(1000),
index=pd.date_range("2000-01-01",periods=1000))
print("\nDaterange up to 1000 days:\n",longer_ts)
# Out:
# Daterange up to 1000 days:
#  2000-01-01   -1.422976
# 2000-01-02    1.189234
# 2000-01-03    0.233084
# 2000-01-04    0.093823
# 2000-01-05    1.544221
#                 ...
# 2002-09-22   -0.795373
# 2002-09-23    0.450270
# 2002-09-24    2.214045
# 2002-09-25   -0.772940
# 2002-09-26    0.988233
# Freq: D, Length: 1000, dtype: float64

# %%
print("\nDate range-2001 year:\n", longer_ts["2001"])
# Out:
# Date range-2001 year:
#  2001-01-01   -1.080157
# 2001-01-02   -0.425157
# 2001-01-03   -1.121439
# 2001-01-04    0.222946
# 2001-01-05   -0.395230
#                 ...
# 2001-12-27   -0.376567
# 2001-12-28    1.908475
# 2001-12-29    1.950364
# 2001-12-30    0.615199
# 2001-12-31   -1.800452
# Freq: D, Length: 365, dtype: float64

# %%
print("\nDate range-05 month 2001 year:\n", longer_ts["2001-05"])
# Out:
# Date range-05 month 2001 year:
#  2001-05-01    1.818265
# 2001-05-02    0.427940
# 2001-05-03   -2.655999
# 2001-05-04    0.643766
# 2001-05-05    0.072615
# 2001-05-06   -2.156115
# 2001-05-07   -0.246389
# 2001-05-08    1.123361
# 2001-05-09   -0.777129
# 2001-05-10    0.528000
# 2001-05-11    1.876754
# 2001-05-12    0.490031
# 2001-05-13   -1.226451
# 2001-05-14   -0.063325
# 2001-05-15    0.114513
# 2001-05-16    1.447333
# 2001-05-17    0.441801
# 2001-05-18    0.228207
# 2001-05-19    1.719983
# 2001-05-20    0.775675
# 2001-05-21   -1.510507
# 2001-05-22    0.521939
# 2001-05-23   -2.016645
# 2001-05-24   -0.218708
# 2001-05-25   -0.734665
# 2001-05-26   -0.385122
# 2001-05-27    1.806796
# 2001-05-28    0.626722
# 2001-05-29   -1.278888
# 2001-05-30   -0.726490
# 2001-05-31    0.322561
# Freq: D, dtype: float64

# %%
print("\nDate range-first few dates in 2000 year:\n",longer_ts["2000"].head())
# Out:
# Date range-first few dates in 2000 year:
#  2000-01-01   -1.422976
# 2000-01-02    1.189234
# 2000-01-03    0.233084
# 2000-01-04    0.093823
# 2000-01-05    1.544221
# Freq: D, dtype: float64

# %%
print("\nDate range-first 15 dates in 02 month 2001 year:\n",longer_ts["2000-02"].head(15))
# Out:
# Date range-first 15 dates in 02 month 2001 year:
#  2000-02-01    0.442843
# 2000-02-02   -0.192543
# 2000-02-03   -0.150075
# 2000-02-04    1.517105
# 2000-02-05    0.779490
# 2000-02-06   -0.586637
# 2000-02-07    1.640586
# 2000-02-08    0.991271
# 2000-02-09    0.075931
# 2000-02-10   -1.084774
# 2000-02-11    1.150780
# 2000-02-12    0.397815
# 2000-02-13    0.851952
# 2000-02-14    0.780623
# 2000-02-15   -0.344081
# Freq: D, dtype: float64

# %%
print("\nDate range-rom 26-9-2001:\n",longer_ts[datetime(2000,9,26):])
# Out:
# Date range-rom 26-9-2001:
#  2000-09-26   -0.370951
# 2000-09-27    0.748202
# 2000-09-28   -0.035060
# 2000-09-29    1.289714
# 2000-09-30    0.707118
#                 ...
# 2002-09-22   -0.795373
# 2002-09-23    0.450270
# 2002-09-24    2.214045
# 2002-09-25   -0.772940
# 2002-09-26    0.988233
# Freq: D, Length: 731, dtype: float64
