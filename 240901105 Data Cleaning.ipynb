# %% [markdown]
# <a href="https://colab.research.google.com/github/sxddxrth/PPML-/blob/main/240901105%20Data%20Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random .randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a  0.417518 -0.088664 -0.009951
# b       NaN       NaN       NaN
# c -0.626969  1.137754 -0.869118
# d  1.163527  1.359775  0.235308
# e       NaN       NaN       NaN
# f  1.738616  0.605339 -0.179499
#
#
# Dropped DataFrame
#          one       two     three
# a  0.417518 -0.088664 -0.009951
# c -0.626969  1.137754 -0.869118
# d  1.163527  1.359775  0.235308
# f  1.738616  0.605339 -0.179499

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','d','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0'.\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a -0.519354 -0.210929  0.610670
# d  0.474318  0.084461  1.410323
# c -0.365998 -0.452071  0.529248
#
#
# NaN replaced with '0'.
#
#         one       two     three
# a -0.519354 -0.210929  0.610670
# d  0.474318  0.084461  1.410323
# c -0.365998 -0.452071  0.529248

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n ")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# original Dataframe:
#          one       two     three
# a -1.269578  0.818720 -0.129523
# b       NaN       NaN       NaN
# c -0.097089  0.341776 -1.021090
# d -1.248785  1.134811  0.111173
# e       NaN       NaN       NaN
# f  0.113611 -1.110408 -1.272097
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5
