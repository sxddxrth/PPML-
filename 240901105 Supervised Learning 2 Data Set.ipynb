# %% [markdown]
# <a href="https://colab.research.google.com/github/sxddxrth/PPML-/blob/main/240901105%20Supervised%20Learning%202%20Data%20Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets

iris = datasets.load_iris()

print("type:")
print(type(iris))

print("\nkeys:")
print(iris.keys())

print("\ntype of data and target:")
print(type(iris.data), type(iris.target))

print("\ndata shape:")
print(iris.data.shape)
# Out:
# type:
# <class 'sklearn.utils._bunch.Bunch'>
#
# keys:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])
#
# type of data and target:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
#
# data shape:
# (150, 4)
